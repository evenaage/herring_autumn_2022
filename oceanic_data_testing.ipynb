# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import rioxarray
import xarray

# %%
ds = nc.Dataset('dataset.nc')
#xr = rioxarray.open_rasterio('dataset.nc')

# %%
for dim in ds.dimensions.values():
    print(dim)

for var in ds.variables.values():
    print(var)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'xc', size = 400
# <class 'netCDF4._netCDF4.Dimension'>: name = 'yc', size = 350
# <class 'netCDF4._netCDF4.Dimension'>: name = 'zc', size = 36
# <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 217
# <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     units: days since 2021-04-01 00:00:00
#     calendar: standard
#     standard_name: time
#     _CoordinateAxisType: Time
# unlimited dimensions: time
# current shape = (217,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 grid_mapping()
#     straight_vertical_longitude_from_pole: 58.0
#     horizontal_resolution: 800.0
#     latitude_of_projection_origin: 90.0
#     longitude_of_projection_origin: 58.0
#     standard_parallel: 60.0
#     origoRef: [0. 0.]
#     false_easting: 2226000.0
#     false_northing: 1916000.0
#     scale_factor_at_projection_origin: 1.0
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 LayerDepths(zc)
#     units: m
#     standard_name: cell_thickness
# unlimited dimensions:
# current shape = (36,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 xc(xc)
#     units: meter
#     standard_name: projection_x_coordinate
#     _CoordinateAxisType: GeoX
# unlimited dimensions:
# current shape = (400,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 yc(yc)
#     units: meter
#     standard_name: projection_y_coordinate
#     _CoordinateAxisType: GeoY
# unlimited dimensions:
# current shape = (350,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 zc(zc)
#     units: m
#     positive: down
#     standard_name: depth
#     _CoordinateAxisType: Height
# unlimited dimensions:
# current shape = (36,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 depth(yc, xc)
#     standard_name: depth
#     units: m
#     SINMODVarID: 351
#     grid_mapping: grid_mapping
#     _FillValue: 9.96921e+36
# unlimited dimensions:
# current shape = (350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# float32 DXxDYy(yc, xc)
#     standard_name: gridSize
#     units: m2
#     SINMODVarID: 354
#     grid_mapping: grid_mapping
#     _FillValue: 9.96921e+36
# unlimited dimensions:
# current shape = (350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# float32 gridLats(yc, xc)
#     SINMODVarID: 21
#     units: degrees_north
#     standard_name: latitude
#     axis: Y
#     _CoordinateAxisType: Lat
# unlimited dimensions:
# current shape = (350, 400)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float32 gridLons(yc, xc)
#     SINMODVarID: 22
#     units: degrees_east
#     standard_name: longitude
#     axis: X
#     _CoordinateAxisType: Lon
# unlimited dimensions:
# current shape = (350, 400)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int16 u-velocity(time, zc, yc, xc)
#     units: m/s
#     scale_factor: 0.00018311106
#     add_offset: 0.0
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 36, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 v-velocity(time, zc, yc, xc)
#     units: m/s
#     scale_factor: 0.00018311106
#     add_offset: 0.0
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 36, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 u-wind(time, yc, xc)
#     units: m/s
#     scale_factor: 0.006103702
#     add_offset: 0.0
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 v-Wind(time, yc, xc)
#     units: m/s
#     scale_factor: 0.006103702
#     add_offset: 0.0
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 w_velocity(time, zc, yc, xc)
#     units: m/s
#     scale_factor: 0.00012207404
#     add_offset: 0.0
#     coordinates: time zc yc xc
#     _CoordinateAxes: time zc yc xc
#     grid_mapping: grid_mapping
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 36, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 temperature(time, zc, yc, xc)
#     standard_name: sea_water_temperature
#     units: K
#     scale_factor: 0.0048829615
#     add_offset: 160.0
#     coordinates: time zc yc xc
#     _CoordinateAxes: time zc yc xc
#     grid_mapping: grid_mapping
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 36, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 salinity(time, zc, yc, xc)
#     standard_name: sea_water_salinity
#     units: ppt
#     scale_factor: 0.0015259255
#     add_offset: 50.0
#     coordinates: time zc yc xc
#     _CoordinateAxes: time zc yc xc
#     grid_mapping: grid_mapping
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 36, 350, 400)
# filling on
# <class 'netCDF4._netCDF4.Variable'>
# int16 elevation(time, yc, xc)
#     standard_name: sea_surface_height_above_sea_level
#     units: m
#     scale_factor: 0.0003051851
#     add_offset: 0.0
#     _FillValue: -32768
#     missing_value: -32768
# unlimited dimensions: time
# current shape = (217, 350, 400)
# filling on

# %%
fig = plt.figure()
for xc in range(400):
    print(xc)
    for yc in range(350):
        plt.plot(ds['temperature'][1, xc, yc, 0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 4
#       2 for xc in range(400):
#       3     for yc in range(350):
# ----> 4         plt.plot(ds['temperature'][1, 0, yc, 0])
#
# File src\netCDF4\_netCDF4.pyx:5022, in netCDF4._netCDF4.Variable.__getitem__()
#
# File c:\Users\eclip\Documents\sild_høst_2022\herring_autumn_2022\.venv\lib\site-packages\numpy\ma\core.py:4211, in MaskedArray.__mul__(self, other)
#    4205     """
#    4206     Subtract self from other, and return a new masked array.
#    4207
#    4208     """
#    4209     return subtract(other, self)
# -> 4211 def __mul__(self, other):
#    4212     "Multiply self by other, and return a new masked array."
#    4213     if self._delegate_binop(other):
#
# KeyboardInterrupt:
